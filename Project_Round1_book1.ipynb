# %% [markdown]
# <a href="https://colab.research.google.com/github/Devu-Goyal/NLP-Project-Round-1/blob/main/Project_Round1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing and Downloading libraries

# %%
import nltk
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Reading novel and Converting in text

# %%
file = open(r"a-town-drowning.txt", encoding='utf-8')
# for preventing next line space
wordList = file.read().splitlines() 
text1 = ""
text1 = text1.join(wordList)

# %%
len(text1) #checking if taken input is large enough
# Out:
# 284698

# %%
# for removing panctuations
punct = '''!()[]{}-+/*=|\/?.,><:;""@#$%^&~`_'''
cleantxt = ""
for i in text1:
  if i not in punct:
    cleantxt = cleantxt + i

# %%
#for converting text in lowercase
text1 = cleantxt
text1 = text1.lower()

# %%
# for removing numbers
text1 = re.sub(r'\d+','',text1) 
text1[:2000]
# Out:
# "novel  takes  right  heart  new  flood  countrythe  northeast  united  states  generally  free  hurricanesand  attendant  floods  disaster  struck  onceterribleand  grim  although  novel  give  accurate  brilliantlyvivid  picture  's  like  live  flood  even  moreimportantly  show  people  like  fought  thecatastrophe  survived  still  fighting  thepersons  starkman  burgess  groff  dynamic  young  executivesharon  shrewd  opportunist  mrs  goudeket  resort  owner  andothers  meet  understand  varying  human  elements  thatthe  flood  unleashed  intensified  sense  agrowing  feeling  pridethat  despite  selfishness  thepeople  town  met  terrible  onslaught  courage  senseof  mutual  help  already  well  known  superb  science  fiction  frederik  pohl  andc  kornbluth  demonstrate  equal  power  realisticcontemporary  novel  chapter  onethe  man  filling  station  clearly  two  minds  butfinally  buttoned  raincoat  pulled  hat  came  outto  mickey  groff  's  car  sorry  make  come  rain  likethis  groff  said  fill  youhe  rolled  window  picked  least  soaked  wad  kleenexto  wipe  mist  inside  windshield  car  radiostopped  playing  show  tunes  began  talk  freezer  food  plansgroff  snapped  leaned  back  watch  turning  dials  thegas  pump  time  man  put  back  cap  sloshed  aroundto  window  groff  exact  change  ready  hand  far  isit  hebertownfive  miles  attendant  said  went  inside  without  counting  themoney  groff  pulled  saw  lights  go  pumps  andthe  big  sign  overheadyou  could  n't  blame  thought  n't  enough  cars  inthis  rain  make  worth  lucky  find  even  onestation  openit  nearly  impossible  see  road  matter  hard  thewindshield  wipers  worked  rain  spraying  somehow  windowswere  closed  tight  groff  could  feel  thin  mist  face  herolled  around  long  downgrade  curve  touched  brakefor  moment  queasy  slipping  sensation  rain  comingdown  faster  could  flow  highwayfoolish  drive  way  hebertown  groff  reflected  theo"

# %%
# for removing white-spaces
def del_whitespace(text1):
  return " ".join(text1.split())
del_whitespace(text1)

# %%
# lemmetisation of text
lemmatizer = WordNetLemmatizer()
def lemmatize (text):
  wrd_token = word_tokenize(text)
  # for providing context
  lemma = [lemmatizer.lemmatize(word, pos='v') for word in wrd_token]
  return lemma

lemmatize(text1)
# Out:
# ['this',
#  'novel',
#  'take',
#  'you',
#  'right',
#  'into',
#  'the',
#  'heart',
#  'of',
#  'the',
#  'new',
#  'flood',
#  'countrythe',
#  'northeast',
#  'unite',
#  'state',
#  'which',
#  'have',
#  'generally',
#  'be',
#  'free',
#  'of',
#  'hurricanesand',
#  'attendant',
#  'flood',
#  'now',
#  'disaster',
#  'have',
#  'strike',
#  'more',
#  'than',
#  'onceterribleand',
#  'grim',
#  'although',
#  'this',
#  'novel',
#  'will',
#  'give',
#  'you',
#  'an',
#  'accurate',
#  'and',
#  'brilliantlyvivid',
#  'picture',
#  'of',
#  'what',
#  'it',
#  "'s",
#  'like',
#  'to',
#  'live',
#  'through',
#  'a',
#  'flood',
#  'even',
#  'moreimportantly',
#  'it',
#  'will',
#  'show',
#  'you',
#  'what',
#  'the',
#  'people',
#  'be',
#  'like',
#  'who',
#  'fight',
#  'thecatastrophe',
#  'and',
#  'how',
#  'those',
#  'who',
#  'survive',
#  'be',
#  'still',
#  'fight',
#  'in',
#  'thepersons',
#  'of',
#  'starkman',
#  'the',
#  'burgess',
#  'groff',
#  'the',
#  'dynamic',
#  'young',
#  'executivesharon',
#  'the',
#  'shrewd',
#  'opportunist',
#  'mrs',
#  'goudeket',
#  'the',
#  'resort',
#  'owner',
#  'andothers',
#  'you',
#  'will',
#  'meet',
#  'and',
#  'understand',
#  'the',
#  'vary',
#  'human',
#  'elements',
#  'thatthe',
#  'flood',
#  'unleash',
#  'and',
#  'intensify',
#  'through',
#  'it',
#  'all',
#  'you',
#  'will',
#  'sense',
#  'agrowing',
#  'feel',
#  'of',
#  'pridethat',
#  'despite',
#  'the',
#  'selfishness',
#  'of',
#  'some',
#  'thepeople',
#  'of',
#  'the',
#  'town',
#  'meet',
#  'the',
#  'terrible',
#  'onslaught',
#  'with',
#  'courage',
#  'and',
#  'a',
#  'senseof',
#  'mutual',
#  'help',
#  'already',
#  'well',
#  'know',
#  'for',
#  'their',
#  'superb',
#  'science',
#  'fiction',
#  'frederik',
#  'pohl',
#  'andc',
#  'm',
#  'kornbluth',
#  'demonstrate',
#  'here',
#  'their',
#  'equal',
#  'power',
#  'in',
#  'the',
#  'realisticcontemporary',
#  'novel',
#  'chapter',
#  'onethe',
#  'man',
#  'in',
#  'the',
#  'fill',
#  'station',
#  'be',
#  'clearly',
#  'of',
#  'two',
#  'mind',
#  'about',
#  'it',
#  'butfinally',
#  'he',
#  'button',
#  'up',
#  'his',
#  'raincoat',
#  'and',
#  'pull',
#  'on',
#  'his',
#  'hat',
#  'and',
#  'come',
#  'outto',
#  'mickey',
#  'groff',
#  "'s",
#  'car',
#  'sorry',
#  'to',
#  'make',
#  'you',
#  'come',
#  'out',
#  'in',
#  'the',
#  'rain',
#  'likethis',
#  'groff',
#  'say',
#  'fill',
#  'it',
#  'up',
#  'will',
#  'youhe',
#  'roll',
#  'up',
#  'the',
#  'window',
#  'and',
#  'pick',
#  'out',
#  'the',
#  'least',
#  'soak',
#  'wad',
#  'of',
#  'kleenexto',
#  'wipe',
#  'the',
#  'mist',
#  'off',
#  'the',
#  'inside',
#  'of',
#  'the',
#  'windshield',
#  'the',
#  'car',
#  'radiostopped',
#  'play',
#  'show',
#  'tune',
#  'and',
#  'begin',
#  'to',
#  'talk',
#  'about',
#  'freezer',
#  'food',
#  'plansgroff',
#  'snap',
#  'it',
#  'off',
#  'and',
#  'lean',
#  'back',
#  'to',
#  'watch',
#  'the',
#  'turn',
#  'dial',
#  'on',
#  'thegas',
#  'pump',
#  'by',
#  'the',
#  'time',
#  'the',
#  'man',
#  'have',
#  'put',
#  'back',
#  'the',
#  'cap',
#  'and',
#  'slosh',
#  'aroundto',
#  'the',
#  'window',
#  'groff',
#  'have',
#  'the',
#  'exact',
#  'change',
#  'ready',
#  'in',
#  'his',
#  'hand',
#  'how',
#  'far',
#  'isit',
#  'to',
#  'hebertownfive',
#  'miles',
#  'the',
#  'attendant',
#  'say',
#  'and',
#  'go',
#  'inside',
#  'without',
#  'count',
#  'themoney',
#  'as',
#  'groff',
#  'pull',
#  'out',
#  'he',
#  'saw',
#  'the',
#  'light',
#  'go',
#  'out',
#  'on',
#  'the',
#  'pump',
#  'andthe',
#  'big',
#  'sign',
#  'overheadyou',
#  'could',
#  "n't",
#  'blame',
#  'him',
#  'he',
#  'think',
#  'there',
#  'be',
#  "n't",
#  'enough',
#  'cars',
#  'out',
#  'inthis',
#  'rain',
#  'to',
#  'make',
#  'it',
#  'worth',
#  'while',
#  'he',
#  'have',
#  'be',
#  'lucky',
#  'to',
#  'find',
#  'even',
#  'onestation',
#  'openit',
#  'be',
#  'nearly',
#  'impossible',
#  'to',
#  'see',
#  'the',
#  'road',
#  'no',
#  'matter',
#  'how',
#  'hard',
#  'thewindshield',
#  'wipers',
#  'work',
#  'rain',
#  'be',
#  'spray',
#  'in',
#  'somehow',
#  'all',
#  'the',
#  'windowswere',
#  'close',
#  'tight',
#  'but',
#  'groff',
#  'could',
#  'feel',
#  'the',
#  'thin',
#  'mist',
#  'on',
#  'his',
#  'face',
#  'herolled',
#  'around',
#  'a',
#  'long',
#  'downgrade',
#  'curve',
#  'and',
#  'when',
#  'he',
#  'touch',
#  'the',
#  'brakefor',
#  'a',
#  'moment',
#  'there',
#  'be',
#  'a',
#  'queasy',
#  'slip',
#  'sensation',
#  'the',
#  'rain',
#  'be',
#  'comingdown',
#  'faster',
#  'than',
#  'it',
#  'could',
#  'flow',
#  'off',
#  'the',
#  'highwayfoolish',
#  'to',
#  'drive',
#  'all',
#  'the',
#  'way',
#  'to',
#  'hebertown',
#  'groff',
#  'reflect',
#  'but',
#  'theonly',
#  'alternative',
#  'actually',
#  'be',
#  'to',
#  'take',
#  'a',
#  'bus',
#  'the',
#  'railroad',
#  "didn'tbother",
#  'much',
#  'with',
#  'this',
#  'little',
#  'outoftheway',
#  'corner',
#  'of',
#  'the',
#  'state',
#  'andthat',
#  'be',
#  'something',
#  'to',
#  'keep',
#  'firmly',
#  'in',
#  'mind',
#  'when',
#  'he',
#  'talk',
#  'to',
#  'the',
#  'burgessthe',
#  'next',
#  'morning',
#  'he',
#  'remind',
#  'himself',
#  'an',
#  'industryhungry',
#  'town',
#  'couldmake',
#  'you',
#  'some',
#  'tempt',
#  'offer',
#  'there',
#  'be',
#  'a',
#  'firm',
#  'promise',
#  'of',
#  'a',
#  'tax',
#  'breakand',
#  'bank',
#  'credit',
#  'and',
#  'the',
#  'suggestion',
#  'that',
#  'maybe',
#  'a',
#  'suitable',
#  'factorybuilding',
#  'could',
#  'be',
#  'turn',
#  'over',
#  'to',
#  'you',
#  'for',
#  'nearly',
#  'nothing',
#  'at',
#  'all',
#  'but',
#  'youhad',
#  'to',
#  'keep',
#  'freight',
#  'differentials',
#  'in',
#  'mind',
#  'too',
#  'and',
#  'what',
#  'about',
#  'laborsupply',
#  'well',
#  'no',
#  'he',
#  'cross',
#  'that',
#  'off',
#  'that',
#  'be',
#  'the',
#  'whole',
#  'point',
#  'of',
#  'theburgess',
#  "'s",
#  'cooperative',
#  'attitude',
#  'hebertown',
#  'have',
#  'plenty',
#  'of',
#  'available',
#  'laborten',
#  'months',
#  'of',
#  'the',
#  'year',
#  'it',
#  'be',
#  'only',
#  'when',
#  'the',
#  'vacationers',
#  'come',
#  'up',
#  'fromnew',
#  'york',
#  'and',
#  'the',
#  'other',
#  'big',
#  'cities',
#  'that',
#  'local',
#  'unemployment',
#  'and',
#  'the',
#  'stateof',
#  'the',
#  'local',
#  'tax',
#  'roll',
#  'cease',
#  'to',
#  'be',
#  'a',
#  'problem',
#  'still',
#  'what',
#  'about',
#  'thatwere',
#  'you',
#  'suppose',
#  'to',
#  'close',
#  'down',
#  'in',
#  'the',
#  'months',
#  'of',
#  'july',
#  'and',
#  'augusthe',
#  'shift',
#  'in',
#  'his',
#  'seat',
#  'force',
#  'himself',
#  'to',
#  'lean',
#  'backit',
#  'do',
#  'no',
#  'goodto',
#  'peer',
#  'into',
#  'the',
#  'rainand',
#  'try',
#  'to',
#  'relax',
#  'mickey',
#  'groff',
#  'be',
#  'a',
#  'big',
#  'manand',
#  'not',
#  'use',
#  'to',
#  'sit',
#  'it',
#  'give',
#  'him',
#  'a',
#  'cramp',
#  'unwelcome',
#  'feel',
#  'ofconfinementthere',
#  'be',
#  'a',
#  'light',
#  'ahead',
#  'it',
#  'turn',
#  'out',
#  'to',
#  'be',
#  'a',
#  'store',
#  'with',
#  'a',
#  'neon',
#  'signthat',
#  'say',
#  'sam',
#  "'s",
#  'grocery',
#  'but',
#  'it',
#  'give',
#  'groff',
#  'enough',
#  'help',
#  'to',
#  'let',
#  'himpick',
#  'up',
#  'his',
#  'speed',
#  'to',
#  'nearly',
#  'thirtyfive',
#  'miles',
#  'an',
#  'hour',
#  'he',
#  'have',
#  'beennearly',
#  'an',
#  'hour',
#  'cover',
#  'the',
#  'last',
#  'twenty',
#  'miles',
#  'he',
#  'saw',
#  'irritably',
#  'ofcourse',
#  'it',
#  'do',
#  "n't",
#  'matterit',
#  'mean',
#  'just',
#  'one',
#  'hour',
#  'less',
#  'to',
#  'spend',
#  'sittingin',
#  'the',
#  'lobby',
#  'of',
#  'the',
#  'heber',
#  'house',
#  'since',
#  'there',
#  'be',
#  "n't",
#  'a',
#  'thing',
#  'he',
#  'could',
#  'dountil',
#  'the',
#  'next',
#  'morning',
#  'in',
#  'this',
#  'rain',
#  'but',
#  'why',
#  'do',
#  'he',
#  'have',
#  'to',
#  'pick',
#  'thisparticular',
#  'thursday',
#  'to',
#  'come',
#  'uphe',
#  'pass',
#  'the',
#  'store',
#  'and',
#  'at',
#  'once',
#  'the',
#  'road',
#  'be',
#  'invisible',
#  'in',
#  'front',
#  'of',
#  'himagain',
#  'he',
#  'tramp',
#  'on',
#  'the',
#  'brake',
#  'slip',
#  'and',
#  'skid',
#  'and',
#  'straightenedout',
#  'that',
#  'be',
#  'foolish',
#  'he',
#  'tell',
#  'himself',
#  'he',
#  'carefully',
#  'slow',
#  'as',
#  'the',
#  'roadcurved',
#  'againnot',
#  'enough',
#  'it',
#  'be',
#  'the',
#  'other',
#  'car',
#  "'s",
#  'fault',
#  'of',
#  'course',
#  'he',
#  'saw',
#  'the',
#  'lightsraging',
#  'at',
#  'him',
#  'down',
#  'the',
#  'middle',
#  'of',
#  'the',
#  'road',
#  'and',
#  'automatically',
#  'pull',
#  'overquickly',
#  'at',
#  'once',
#  'he',
#  'felt',
#  'the',
#  'sidewise',
#  'slip',
#  'and',
#  'sway',
#  'of',
#  'the',
#  'skid',
#  'butit',
#  'be',
#  'too',
#  'late',
#  'to',
#  'do',
#  'anything',
#  'about',
#  'it',
#  'it',
#  'could',
#  'have',
#  'be',
#  'worse',
#  'thank',
#  'god',
#  'there',
#  'be',
#  'a',
#  'good',
#  'wide',
#  'shoulderright',
#  'there',
#  'the',
#  'only',
#  'thing',
#  'be',
#  'he',
#  'seem',
#  'to',
#  'be',
#  'stick',
#  'in',
#  'the',
#  'mudmickey',
#  'groff',
#  'be',
#  "n't",
#  'much',
#  'of',
#  'a',
#  'waiter',
#  'there',
#  'be',
#  "n't",
#  'a',
#  'showdog',
#  "'s",
#  'chanceof',
#  'a',
#  'car',
#  'stop',
#  'to',
#  'help',
#  'him',
#  'of',
#  'courseeven',
#  'if',
#  'one',
#  'come',
#  'by',
#  "they'dhardly",
#  'be',
#  'able',
#  'to',
#  'see',
#  'him',
#  'anyway',
#  'sam',
#  "'s",
#  'grocery',
#  'could',
#  "n't",
#  'be',
#  'more',
#  'thana',
#  'quarter',
#  'of',
#  'a',
#  'mile',
#  'back',
#  'along',
#  'the',
#  'road',
#  'and',
#  'from',
#  'there',
#  'he',
#  'could',
#  'phonefor',
#  'a',
#  'wreckeror',
#  'at',
#  'worst',
#  'if',
#  'the',
#  'wreckers',
#  'have',
#  'their',
#  'own',
#  'problems',
#  'ona',
#  'night',
#  'like',
#  'this',
#  'for',
#  'a',
#  'cab',
#  'to',
#  'get',
#  'him',
#  'into',
#  'hebertown',
#  'once',
#  'the',
#  'rainstopped',
#  'it',
#  'would',
#  "n't",
#  'be',
#  'much',
#  'of',
#  'a',
#  'problem',
#  'to',
#  'get',
#  'pull',
#  'out',
#  'of',
#  'the',
#  'mudhe',
#  'almost',
#  'change',
#  'his',
#  'mind',
#  'when',
#  'he',
#  'step',
#  'out',
#  'into',
#  'the',
#  'rain',
#  'but',
#  'bythe',
#  'time',
#  'he',
#  'have',
#  'lock',
#  'the',
#  'car',
#  'door',
#  'behind',
#  'him',
#  'it',
#  'be',
#  'too',
#  'lateit',
#  'washard',
#  'to',
#  'imagine',
#  'how',
#  'he',
#  'could',
#  'get',
#  'any',
#  'wetter',
#  'than',
#  'he',
#  'be',
#  'mickey',
#  'groffhad',
#  'hear',
#  'of',
#  'rain',
#  'come',
#  'down',
#  'in',
#  'sheet',
#  'but',
#  'he',
#  'have',
#  'never',
#  'experiencedit',
#  'before',
#  'this',
#  'be',
#  'something',
#  'beyond',
#  'all',
#  'expectations',
#  'in',
#  'ten',
#  'secondshe',
#  'be',
#  'wet',
#  'to',
#  'the',
#  'skin',
#  'in',
#  'a',
#  'minute',
#  'he',
#  'be',
#  'drench',
#  'as',
#  'a',
#  'channelswimmer',
#  'there',
#  'be',
#  ...]

# %% [markdown]
# Tokenization

# %%
tokens = word_tokenize(text1)
freq = nltk.FreqDist(tokens)
freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1],reverse=True)}
x = list(freq.keys())[:50]
y = list(freq.values())[:50]
plt.figure(figsize=(12,5))
plt.plot(x,y,c='r',lw=4,ls='-.')
plt.grid()
plt.xticks(rotation=90)
plt.title('Token Frequency (with stopwords)',size=20)
plt.xlabel('Words',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %%
#wordcloud with stopwords
wordcloud = WordCloud(width = 600, height = 400, background_color ='black', min_font_size = 8,stopwords = {},colormap='winter').generate(text1) 
plt.figure(figsize = (10,8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
# Removing stopwords
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text1)
tokens_final = [i for i in tokens if not i in stop_words] # tokenising with removing stopwords
finaltext = "  "
finaltext = finaltext.join(tokens_final)
text1 = finaltext

# %%
# Word cloud after removing stopwords
wordcloud = WordCloud(width = 600, height = 400, background_color ='black', min_font_size = 8,stopwords = {},colormap='winter').generate(text1) 
plt.figure(figsize = (12,8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
tokens = word_tokenize(text1)
freq = nltk.FreqDist(tokens)
freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1],reverse=True)}
x = list(freq.keys())[:50]
y = list(freq.values())[:50]
plt.figure(figsize=(10,5))
plt.plot(x,y,c='r',lw=4,ls='-.')
plt.grid()
plt.xticks(rotation=90)
plt.title('Token Frequency (without stopwords)',size=20)
plt.xlabel('Words',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %%
import numpy as np
bin_size=np.linspace(0,20)
wordLength = [len(r) for r in tokens]

#Plotting histogram of Word length vs Frequency
plt.hist(wordLength, bins=bin_size)
plt.xlabel('word length')
plt.ylabel('word length Frequency')
plt.title('Frequency Distribution for the book Drowning town')
plt.show()

# %%
tagged = nltk.pos_tag(tokens) 
tagged[:50] #first 50 POS tags
# Out:
# [('novel', 'JJ'),
#  ('takes', 'VBZ'),
#  ('right', 'JJ'),
#  ('heart', 'NN'),
#  ('new', 'JJ'),
#  ('flood', 'NN'),
#  ('countrythe', 'NN'),
#  ('northeast', 'NN'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('generally', 'RB'),
#  ('free', 'JJ'),
#  ('hurricanesand', 'NN'),
#  ('attendant', 'NN'),
#  ('floods', 'NNS'),
#  ('disaster', 'NN'),
#  ('struck', 'VBD'),
#  ('onceterribleand', 'RB'),
#  ('grim', 'JJ'),
#  ('although', 'IN'),
#  ('novel', 'JJ'),
#  ('give', 'JJ'),
#  ('accurate', 'NN'),
#  ('brilliantlyvivid', 'NN'),
#  ('picture', 'NN'),
#  ("'s", 'POS'),
#  ('like', 'IN'),
#  ('live', 'JJ'),
#  ('flood', 'NN'),
#  ('even', 'RB'),
#  ('moreimportantly', 'RB'),
#  ('show', 'VBP'),
#  ('people', 'NNS'),
#  ('like', 'IN'),
#  ('fought', 'JJ'),
#  ('thecatastrophe', 'NN'),
#  ('survived', 'VBD'),
#  ('still', 'RB'),
#  ('fighting', 'VBG'),
#  ('thepersons', 'NNS'),
#  ('starkman', 'JJ'),
#  ('burgess', 'NN'),
#  ('groff', 'NN'),
#  ('dynamic', 'JJ'),
#  ('young', 'JJ'),
#  ('executivesharon', 'NN'),
#  ('shrewd', 'JJ'),
#  ('opportunist', 'NN'),
#  ('mrs', 'NN'),
#  ('goudeket', 'NN')]

# %%
from collections import Counter
counts = Counter( tag for word,  tag in tagged)
print(counts)
# Out:
# Counter({'NN': 8844, 'JJ': 4300, 'VBD': 2450, 'RB': 2217, 'NNS': 1788, 'VBP': 1237, 'VB': 1093, 'VBG': 1062, 'VBN': 809, 'MD': 606, 'IN': 523, 'POS': 442, 'CD': 308, 'VBZ': 237, 'PRP': 65, 'JJR': 64, 'RP': 55, 'RBR': 54, 'DT': 53, 'JJS': 47, 'WP': 33, 'NNP': 25, 'FW': 18, 'CC': 16, 'WDT': 11, 'EX': 10, "''": 10, 'WRB': 7, 'WP$': 3, 'RBS': 2, 'PRP$': 1, 'UH': 1})

# %%
freq_tags = nltk.FreqDist(counts)
freq_tags = {k: v for k, v in sorted(freq_tags.items(), key=lambda item: item[1],reverse=True)}
x = list(freq_tags.keys())[:50]
y = list(freq_tags.values())[:50]
plt.figure(figsize=(10,5))
plt.plot(x,y,c='b',lw=4,ls='-')
plt.grid()
plt.xticks(rotation=90)
plt.title('TAGs Frequency',size=20)
plt.xlabel('Tags',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %% [markdown]
# # New Section
